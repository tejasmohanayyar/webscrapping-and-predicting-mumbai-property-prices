# %%
import pandas as pd
import os
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import warnings
warnings.simplefilter('ignore')

# %%
# Out:
#      Area_Type      Possession_Status               Floors new_or_resale  \
# 0  carpet area  Possession by Mar '22                  NaN  New Property
# 1  carpet area          Ready to Move                  NaN  New Property
# 2  carpet area  Possession by Jun '24  19 out of 23 floors  New Property
# 3  carpet area  Possession by Dec '23                  NaN  New Property
# 4  carpet area  Possession by Jun '21   1 out of 42 floors  New Property
#
#        furnishing            society  bathrooms            advertiser_name  \
# 0  Semi-Furnished       Nahar Olivia        2.0                Amey Sawant
# 1     Unfurnished    Ekta Parksville        2.0                 Ekta World
# 2     Unfurnished     GS 47th Avenue        2.0                   GS GROUP
# 3     Unfurnished  Bachraj Lifespace        1.0         Bachraj Developers
# 4     Unfurnished   Northern Heights        2.0  N Rose Developers Pvt Ltd
#
#           bhk       price    parking  \
# 0  2 BHK Flat   ₹ 1.67 Cr  1 Covered
# 1  2 BHK Flat  ₹ 50.7 Lac  1 Covered
# 2  2 BHK Flat   ₹ 1.03 Cr        NaN
# 3  2 BHK Flat    ₹ 52 Lac        NaN
# 4  2 BHK Flat   ₹ 1.50 Cr  1 Covered
#
#                                             comments  \
# 0  Olivia is a part of Nahar's Amrit Shakti, an a...
# 1  Ekta Parksville, is a 15-storey high-rise luxu...
# 2  GS 47TH AVENUE in VIKHROLI EAST, Central Mumba...
# 3  Welcome to Bachraj Lifespace, a modern-day lux...
# 4  Well designed with a keen eye on aesthetics an...
#
#                                    location date_of_posting facing  \
# 0        ['Nahar Olivia,', 'in Chandivali']     Jan 30, '21    NaN
# 1     ['Ekta Parksville,', 'in Virar West']     Jan 30, '21    NaN
# 2   ['GS 47th Avenue,', 'in Vikhroli East']     Jan 28, '21    NaN
# 3   ['Bachraj Lifespace,', 'in Virar West']     Jan 30, '21    NaN
# 4  ['Northern Heights,', 'in Dahisar East']     Jan 28, '21    NaN
#
#   overlooking      area
# 0         NaN  653 sqft
# 1         NaN  583 sqft
# 2         NaN  545 sqft
# 3         NaN  568 sqft
# 4         NaN  656 sqft
